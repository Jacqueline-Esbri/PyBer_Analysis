# %%
import matplotlib.pyplot as plt

# %%
savings = [0,100,150,200,300,500,300,350,500,600,750,1000]
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# %%
# Note: Months is the X variable and Savings is the Y variable
#X Var. always first  position

plt.plot(months, savings)
plt.xlabel('Month')
plt.ylabel('Savings ($)')
plt.title('Savings Account Results')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#The above is an example from 5.1.3 video
